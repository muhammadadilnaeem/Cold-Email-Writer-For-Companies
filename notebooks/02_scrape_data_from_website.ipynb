# %% [markdown]
# -----
#
# # **Scrape Website Data Using Langchain's WebBaseLoader and Experiment with It**
#
#
# ------

# %% [markdown]
# ### **How to use groq to query**

# %%
# importing Libraries
import os
import json
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
groq_api_key = os.getenv("GROQ_API_KEY")

llm = ChatGroq(
    temperature=0.3,
    groq_api_key=groq_api_key,
    model_name= "Llama-3.1-8b-Instant",

)

response = llm.invoke("what is the meaning of life?")   
print(response.content)
# Out:
# The meaning of life is a complex and multifaceted question that has been debated by philosophers, theologians, scientists, and thinkers for centuries. There is no one definitive answer, and it may vary depending on cultural, personal, and individual perspectives.
#
# Some possible perspectives on the meaning of life include:
#
# 1. **Biological perspective**: From a biological standpoint, the meaning of life is to survive and reproduce. This is the fundamental drive of all living organisms, and it is the basis for the continuation of species.
# 2. **Psychological perspective**: From a psychological perspective, the meaning of life is to find happiness, fulfillment, and purpose. This can be achieved through personal growth, relationships, and contributing to society.
# 3. **Philosophical perspective**: Philosophers have proposed various theories about the meaning of life, including:
#  * **Existentialism**: Life has no inherent meaning, and it is up to individuals to create their own purpose and meaning.
#  * **Absurdism**: Life is inherently meaningless, and the search for meaning is a futile endeavor.
#  * **Stoicism**: The meaning of life is to live in accordance with reason and virtue, and to accept the natural order of things.
# 4. **Spiritual perspective**: Many spiritual traditions believe that the meaning of life is to connect with a higher power or the divine, and to fulfill one's spiritual purpose.
# 5. **Humanistic perspective**: From a humanistic perspective, the meaning of life is to strive for human flourishing, and to cultivate our unique potential and talents.
# 6. **Scientific perspective**: Some scientists believe that the meaning of life is to understand the universe and our place in it, and to contribute to the advancement of knowledge and human progress.
#
# Ultimately, the meaning of life is a deeply personal and subjective question that each individual must answer for themselves. It may involve a combination of these perspectives, or something entirely new and unique.
#
# Some famous quotes that touch on the meaning of life include:
#
# * "The only true wisdom is in knowing you know nothing." - Socrates
# * "The purpose of life is to find your gift. The meaning of life is to give it away." - Pablo Picasso
# * "The meaning of life is to find your why. Your purpose. Your reason for being." - Simon Sinek
# * "The question isn't who is going to let me; it's who is going to stop me." - Ayn Rand
#
# What do you think is the meaning of life?

# %% [markdown]
# ### **Setting up WebBaseLoader**

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://jobs.nike.com/job/R-33460")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Search JobsSkip navigationSearch JobsNIKE, INC. JOBSContract JobsJoin The Talent CommunityLife @ NikeOverviewBenefitsBrandsOverviewJordanConverseTeamsOverviewAdministrative SupportAdvanced InnovationAir Manufacturing InnovationAviationCommunicationsCustomer ServiceDesignDigitalFacilitiesFinance & AccountingGovernment & Public AffairsHuman ResourcesInsights & AnalyticsLegalManufacturing & EngineeringMarketingMerchandisingPlanningPrivacyProcurementProduct Creation, Development & ManagementRetail CorporateRetail StoresSalesSocial & Community ImpactSports MarketingStrategic PlanningSupply Chain, Distribution & LogisticsSustainabilityTechnologyLocationsOverviewNike WHQNike New York HQEHQ: Hilversum, The NetherlandsELC: Laakdal, BelgiumGreater China HQDiversity, Equity & InclusionOverviewMilitary InclusionDisability InclusionIndigenous InclusionInternshipsGIFT CARDSPROMOTIONSFIND A STORESIGN UP FOR EMAILBECOME A MEMBERNIKE JOURNALSEND US FEEDBACKGET HELPGET HELPOrder StatusShipping and DeliveryReturnsPayment OptionsGift Cards BalanceContact UsABOUT NIKEABOUT NIKENewsCareersInvestorsPurposeSustainabilityUnited States© 2024 Nike, Inc. All Rights ReservedGuidesNike AdaptNike Air MaxNike FlyleatherNike ReactSpace HippieNike AirNike FlyEaseNike Free Nike VaporflyNike Air Force 1 Nike FlyknitNike JoyrideNike ZoomXTerms of SaleTerms of UseNike Privacy PolicyYour Privacy ChoicesCA Supply Chain Act

# %% [markdown]
# ### **Create a Prompt Template**

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
    """
    ### SCRAPED TEXT FROM WEBSITE:
    {page_data}
    ### INSTRUCTION:
    The scraped text is from the careers page of a website.
    Your job is to extract the job postings and return them in JSON format containing the 
    following keys: `role`, `experience`, `skills`, and `description`.
    Ensure each key contains accurate and relevant information. 
    If some information is not available, leave that field empty but include the key.
    **Do not include any additional text, only return the JSON object.**
    ### VALID JSON OUTPUT (NO PREAMBLE):
    """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %% [markdown]
# ### **Load data in json**

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'Administrative Support': {'role': 'Administrative Support',
#   'experience': '',
#   'skills': '',
#   'description': 'Supports the day-to-day activities of the team, including administrative tasks, data entry, and other duties as assigned.'},
#  'Advanced Innovation': {'role': 'Advanced Innovation',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements innovative solutions to drive business growth and improve operational efficiency.'},
#  'Air Manufacturing Innovation': {'role': 'Air Manufacturing Innovation',
#   'experience': '',
#   'skills': '',
#   'description': 'Drives innovation in air manufacturing, including the development of new products, processes, and technologies.'},
#  'Aviation': {'role': 'Aviation',
#   'experience': '',
#   'skills': '',
#   'description': 'Supports the development and implementation of aviation-related projects and initiatives.'},
#  'Communications': {'role': 'Communications',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements internal and external communications strategies to support business objectives.'},
#  'Customer Service': {'role': 'Customer Service',
#   'experience': '',
#   'skills': '',
#   'description': 'Provides exceptional customer service and support to internal and external customers.'},
#  'Design': {'role': 'Design',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements design concepts and strategies to drive business growth and improve product quality.'},
#  'Digital': {'role': 'Digital',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements digital solutions to drive business growth and improve operational efficiency.'},
#  'Facilities': {'role': 'Facilities',
#   'experience': '',
#   'skills': '',
#   'description': 'Supports the maintenance and upkeep of facilities, including maintenance, repairs, and renovations.'},
#  'Finance & Accounting': {'role': 'Finance & Accounting',
#   'experience': '',
#   'skills': '',
#   'description': 'Provides financial and accounting support to the business, including budgeting, forecasting, and financial analysis.'},
#  'Government & Public Affairs': {'role': 'Government & Public Affairs',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements government and public affairs strategies to support business objectives.'},
#  'Human Resources': {'role': 'Human Resources',
#   'experience': '',
#   'skills': '',
#   'description': 'Supports the recruitment, retention, and development of employees, including HR-related initiatives and programs.'},
#  'Insights & Analytics': {'role': 'Insights & Analytics',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements insights and analytics solutions to drive business growth and improve operational efficiency.'},
#  'Legal': {'role': 'Legal',
#   'experience': '',
#   'skills': '',
#   'description': 'Provides legal support to the business, including contract review, negotiation, and dispute resolution.'},
#  'Manufacturing & Engineering': {'role': 'Manufacturing & Engineering',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements manufacturing and engineering solutions to drive business growth and improve product quality.'},
#  'Marketing': {'role': 'Marketing',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements marketing strategies to drive business growth and improve brand awareness.'},
#  'Merchandising': {'role': 'Merchandising',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements merchandising strategies to drive business growth and improve product assortment.'},
#  'Planning': {'role': 'Planning',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements planning strategies to drive business growth and improve operational efficiency.'},
#  'Privacy': {'role': 'Privacy',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements privacy strategies to protect customer and employee data.'},
#  'Procurement': {'role': 'Procurement',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements procurement strategies to drive business growth and improve operational efficiency.'},
#  'Product Creation, Development & Management': {'role': 'Product Creation, Development & Management',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements product creation, development, and management strategies to drive business growth and improve product quality.'},
#  'Retail Corporate': {'role': 'Retail Corporate',
#   'experience': '',
#   'skills': '',
#   'description': 'Supports the development and implementation of retail corporate initiatives and programs.'},
#  'Retail Stores': {'role': 'Retail Stores',
#   'experience': '',
#   'skills': '',
#   'description': 'Supports the operation and maintenance of retail stores, including sales, customer service, and inventory management.'},
#  'Sales': {'role': 'Sales',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements sales strategies to drive business growth and improve revenue.'},
#  'Social & Community Impact': {'role': 'Social & Community Impact',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements social and community impact initiatives and programs to drive business growth and improve brand reputation.'},
#  'Sports Marketing': {'role': 'Sports Marketing',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements sports marketing strategies to drive business growth and improve brand awareness.'},
#  'Strategic Planning': {'role': 'Strategic Planning',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements strategic planning strategies to drive business growth and improve operational efficiency.'},
#  'Supply Chain, Distribution & Logistics': {'role': 'Supply Chain, Distribution & Logistics',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements supply chain, distribution, and logistics strategies to drive business growth and improve operational efficiency.'},
#  'Sustainability': {'role': 'Sustainability',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements sustainability strategies to drive business growth and improve environmental impact.'},
#  'Technology': {'role': 'Technology',
#   'experience': '',
#   'skills': '',
#   'description': 'Develops and implements technology solutions to drive business growth and improve operational efficiency.'}}

# %%
type(json_res)
# Out:
# dict

# %% [markdown]
# ### **Load an Example Dataset**

# %%
import pandas as pd

df = pd.read_csv(r"E:\Cold Email Generater\my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %% [markdown]
# ### **Insert it into Chromadb**

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %% [markdown]
# ### **Let's Query**

# %%
links = collection.query(query_texts=['Experience in Python', "Experties in React"], n_results=2).get("metadatas")
links
# Out:
# [[{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}],
#  [{'links': 'https://example.com/react-portfolio'},
#   {'links': 'https://example.com/react-native-portfolio'}]]

# %%
job
# Out:
# {'Administrative Support': {'role': 'Administrative Support',
#   'experience': '',
#   'skills': '',
#   'description': 'Support the day-to-day operations of the business, ensuring the smooth delivery of administrative tasks and projects.'},
#  'Advanced Innovation': {'role': 'Advanced Innovation',
#   'experience': '',
#   'skills': '',
#   'description': 'Drive innovation and experimentation to develop new products, services, and business models that meet the evolving needs of consumers.'},
#  'Air Manufacturing Innovation': {'role': 'Air Manufacturing Innovation',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement innovative manufacturing processes and technologies to improve efficiency, quality, and sustainability.'},
#  'Aviation': {'role': 'Aviation',
#   'experience': '',
#   'skills': '',
#   'description': ''},
#  'Communications': {'role': 'Communications',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective communication strategies to engage stakeholders, build brand awareness, and drive business results.'},
#  'Customer Service': {'role': 'Customer Service',
#   'experience': '',
#   'skills': '',
#   'description': 'Provide exceptional customer service and support to ensure customer satisfaction and loyalty.'},
#  'Design': {'role': 'Design',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop innovative and stylish designs that meet the evolving needs of consumers and drive business results.'},
#  'Digital': {'role': 'Digital',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement digital strategies to drive business results, improve customer engagement, and enhance the brand experience.'},
#  'Facilities': {'role': 'Facilities',
#   'experience': '',
#   'skills': '',
#   'description': 'Manage and maintain the physical facilities and infrastructure to ensure a safe and productive work environment.'},
#  'Finance & Accounting': {'role': 'Finance & Accounting',
#   'experience': '',
#   'skills': '',
#   'description': 'Provide financial planning, analysis, and reporting to support business decision-making and drive financial performance.'},
#  'Government & Public Affairs': {'role': 'Government & Public Affairs',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective government and public affairs strategies to build relationships, influence policy, and drive business results.'},
#  'Human Resources': {'role': 'Human Resources',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement HR strategies to attract, retain, and develop top talent, drive business results, and enhance the employee experience.'},
#  'Insights & Analytics': {'role': 'Insights & Analytics',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement data-driven insights and analytics to drive business decision-making and improve performance.'},
#  'Jordan': {'role': 'Jordan',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategies to drive business results, build brand awareness, and enhance the consumer experience for the Jordan brand.'},
#  'Manufacturing & Engineering': {'role': 'Manufacturing & Engineering',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement innovative manufacturing processes and technologies to improve efficiency, quality, and sustainability.'},
#  'Marketing': {'role': 'Marketing',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective marketing strategies to drive business results, build brand awareness, and enhance the consumer experience.'},
#  'Merchandising': {'role': 'Merchandising',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement merchandising strategies to drive business results, build brand awareness, and enhance the consumer experience.'},
#  'Planning': {'role': 'Planning',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategic plans to drive business results, improve performance, and enhance the consumer experience.'},
#  'Privacy': {'role': 'Privacy',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective privacy strategies to protect consumer data and enhance the consumer experience.'},
#  'Procurement': {'role': 'Procurement',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective procurement strategies to drive business results, improve performance, and enhance the supplier experience.'},
#  'Product Creation, Development & Management': {'role': 'Product Creation, Development & Management',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategies to drive product innovation, development, and management to meet the evolving needs of consumers.'},
#  'Retail Corporate': {'role': 'Retail Corporate',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategies to drive business results, improve performance, and enhance the consumer experience for retail corporate.'},
#  'Retail Stores': {'role': 'Retail Stores',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategies to drive business results, improve performance, and enhance the consumer experience for retail stores.'},
#  'Sales': {'role': 'Sales',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective sales strategies to drive business results, improve performance, and enhance the consumer experience.'},
#  'Social & Community Impact': {'role': 'Social & Community Impact',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategies to drive social and community impact, improve performance, and enhance the consumer experience.'},
#  'Sports Marketing': {'role': 'Sports Marketing',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective sports marketing strategies to drive business results, build brand awareness, and enhance the consumer experience.'},
#  'Strategic Planning': {'role': 'Strategic Planning',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement strategic plans to drive business results, improve performance, and enhance the consumer experience.'},
#  'Supply Chain, Distribution & Logistics': {'role': 'Supply Chain, Distribution & Logistics',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective supply chain, distribution, and logistics strategies to drive business results, improve performance, and enhance the supplier experience.'},
#  'Sustainability': {'role': 'Sustainability',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective sustainability strategies to drive business results, improve performance, and enhance the consumer experience.'},
#  'Technology': {'role': 'Technology',
#   'experience': '',
#   'skills': '',
#   'description': 'Develop and implement effective technology strategies to drive business results, improve performance, and enhance the consumer experience.'}}

# %%
job = json_res

# %% [markdown]
# ### **Define a Prompt Template TO GENERATE A COLD EMAIL**

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Raheel, a business development executive at AtliQ. AtliQ is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Atliq's portfolio: {link_list}
        Remember you are Raheel, BDE at AtliQ. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Unlock Business Efficiency with AtliQ's Expert Solutions
#
# Dear [Client Name],
#
# I hope this email finds you well. My name is Raheel, and I am a Business Development Executive at AtliQ, a leading AI & Software Consulting company. We specialize in streamlining business processes through automated tools, empowering enterprises to achieve scalability, process optimization, cost reduction, and enhanced overall efficiency.
#
# I came across your job description for a [Job Title] role, and I believe AtliQ's expertise can significantly contribute to your organization's success. Our team has a proven track record of delivering tailored solutions that address the unique needs of our clients.
#
# Some of the key areas where we can provide value include:
#
# - **Digital Solutions**: We can help you develop and implement digital solutions to drive business growth and improve operational efficiency. Our expertise in [React](https://example.com/react-portfolio) and [React Native](https://example.com/react-native-portfolio) can help you create engaging user experiences and enhance your online presence.
# - **AI & Machine Learning**: Our team has experience in [Machine Learning with Python](https://example.com/ml-python-portfolio) and [Python Development](https://example.com/python-portfolio), which can help you leverage the power of AI to automate processes, predict outcomes, and make data-driven decisions.
# - **Business Process Optimization**: We can help you streamline your business processes, reduce costs, and improve overall efficiency. Our expertise in [Supply Chain, Distribution & Logistics](https://example.com/supply-chain-portfolio) and [Sustainability](https://example.com/sustainability-portfolio) can help you create a more agile and environmentally friendly organization.
#
# AtliQ's portfolio includes a wide range of successful projects, such as:
#
# - Developing a [Machine Learning Model](https://example.com/ml-model-portfolio) that predicted customer churn and helped a leading telecom company reduce customer loss by 25%.
# - Creating a [Digital Platform](https://example.com/digital-platform-portfolio) that enabled a retail company to increase online sales by 50% and reduce customer support queries by 30%.
# - Implementing a [Supply Chain Optimization](https://example.com/supply-chain-portfolio) solution that helped a manufacturing company reduce inventory costs by 20% and improve delivery times by 15%.
#
# I would be delighted to discuss how AtliQ's expertise can help your organization achieve its goals. Please feel free to contact me at [raheel@atliq.com](mailto:raheel@atliq.com) or schedule a call at your convenience.
#
# Thank you for considering AtliQ as a potential partner. I look forward to the opportunity to collaborate with you.
#
# Best regards,
#
# Raheel
# Business Development Executive
# AtliQ
